# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
key = "CURRFX/USDCNY"

# %%
import quandl

# %%
values = quandl.get(key, returns="numpy", rows=100, order="desc")

# %%
values[0]
# Out:
# (datetime.datetime(2017, 6, 5, 0, 0), 6.8127999305725, 6.813000202179, 6.7699999809265)

# %%
xs = [x[0] for x in values[:30]]
ys = [x[1] for x in values[:30]]

# %%
plt.plot(xs, ys)
